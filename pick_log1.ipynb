# %%
#!/usr/bin/env python3
import csv
import sys
import pandas as pd
import os
import os.path
import datetime
import glob

out_dir = "log1/"
os.makedirs(out_dir, exist_ok=True)

# import csv files
import_file = 'C:/Users/0296/Desktop/firstChiceDataAnalysis/out/PT_2023-01-11_2023-12-01.csv'
df_import = pd.read_csv(import_file, names = range(1,4,1), encoding="shift_jis", delimiter=",", dtype="object")
df_import[1] = (pd.to_datetime(df_import[1])).dt.round("min")
df_import[2] = (pd.to_datetime(df_import[2])).dt.round("min")

log1_dir = "//172.25.0.195/fte_data (東日本)/【東京支社】/1.計画物件/3一般企業/ファーストチョイス㈱/ハンバーグフリーザー/HANEW本社監査指摘事項/運転データ/Package1/各所温度_log"
output_dir = 'C:/Users/0296/Desktop/firstChiceDataAnalysis/'
os.chdir(log1_dir)
log1_list = glob.glob("LOG00001_*.CSV")

# %%
data = {1:[], 18:[], 19:[]}
df_out = pd.DataFrame(data)
df_out[1] = (pd.to_datetime(df_out[1])).dt.round("min")
n = 0

for log in log1_list:
    os.chdir(log1_dir)
    df = pd.read_csv(log, names = range(1,20,1), encoding="shift_jis", delimiter=",", dtype="object")
    _df = df[13:]
    _df = _df.drop(range(2,18,1), axis=1)
    _df[1] = (pd.to_datetime(_df[1])).dt.round("min")

    for i in range(0,len(df_import)):
        t_i = df_import.iloc[i,0]
        t_o = df_import.iloc[i,1]
        for j in range(0,len(_df)):
            t = _df.iloc[j,0]
            if t.date() == t_i.date():
                t1 = int((t - t_i).seconds)
                t2 = int((t_o - t).seconds)
                t3 = int((t_o - t_i).seconds)
                if t1+t2==t3:
                    df_out = pd.concat([df_out,_df[j:j+1]], ignore_index=False)
                elif t1==t2+t3:
                    break
            elif (t - t_i).days > 0:
                break
    
    print('n={0}:{1} END'.format(n,log))
    n = n + 1
    col_names = {1: 'Time',18: '冷却水送り温度',19: '排熱回収補給水温度'}
    # if n > len(log1_list):
    #     os.chdir(output_dir)
    #     df_out = df_out.rename(columns=col_names)
    #     df_out.to_csv(out_dir+"picked_log01_{:02}.csv".format(int(n/10)), encoding="shift_jis", index=False)
    #     print('picked_log01_{:02}.csv SAVED'.format(int(n/10)))
    #     print('ALL END')
    #     break
    # elif n!=0 and n%10==0:
    #     os.chdir(output_dir)
    #     df_out = df_out.rename(columns=col_names)
    #     df_out.to_csv(out_dir+"picked_log01_{:02}.csv".format(int(n/10)), encoding="shift_jis", index=False)
    #     print('picked_log01_{:02}.csv SAVED'.format(int(n/10)))
    #     df_out = pd.DataFrame(data)
    #     df_out[1] = (pd.to_datetime(df_out[1])).dt.round("min")
os.chdir(output_dir)
df_out = df_out.rename(columns=col_names)
df_out.to_csv(out_dir+"picked_log01.csv", encoding="shift_jis", index=False)
# Out:
# n=0:LOG00001_0001.CSV END
# n=1:LOG00001_0002.CSV END
# n=2:LOG00001_0003.CSV END
# n=3:LOG00001_0004.CSV END
# n=4:LOG00001_0005.CSV END
# n=5:LOG00001_0006.CSV END
# n=6:LOG00001_0007.CSV END
# n=7:LOG00001_0008.CSV END
# n=8:LOG00001_0009.CSV END
# n=9:LOG00001_0010.CSV END
# n=10:LOG00001_0011.CSV END
# n=11:LOG00001_0012.CSV END
# n=12:LOG00001_0013.CSV END
# n=13:LOG00001_0014.CSV END
# n=14:LOG00001_0015.CSV END
# n=15:LOG00001_0016.CSV END
# n=16:LOG00001_0017.CSV END
# n=17:LOG00001_0018.CSV END
# n=18:LOG00001_0019.CSV END
# n=19:LOG00001_0020.CSV END
# n=20:LOG00001_0021.CSV END
# n=21:LOG00001_0022.CSV END
# n=22:LOG00001_0023.CSV END
# n=23:LOG00001_0024.CSV END
# n=24:LOG00001_0025.CSV END
# n=25:LOG00001_0026.CSV END
# n=26:LOG00001_0027.CSV END
# n=27:LOG00001_0028.CSV END
# n=28:LOG00001_0029.CSV END
# n=29:LOG00001_0030.CSV END
# n=30:LOG00001_0031.CSV END
# n=31:LOG00001_0032.CSV END
# n=32:LOG00001_0033.CSV END
# n=33:LOG00001_0034.CSV END
# n=34:LOG00001_0035.CSV END
# n=35:LOG00001_0036.CSV END
# n=36:LOG00001_0037.CSV END
# n=37:LOG00001_0038.CSV END
# n=38:LOG00001_0039.CSV END
# n=39:LOG00001_0040.CSV END
# n=40:LOG00001_0041.CSV END
# n=41:LOG00001_0042.CSV END
# n=42:LOG00001_0043.CSV END
# n=43:LOG00001_0044.CSV END
# n=44:LOG00001_0045.CSV END
# n=45:LOG00001_0046.CSV END
# n=46:LOG00001_0047.CSV END
# n=47:LOG00001_0048.CSV END
# n=48:LOG00001_0049.CSV END
# n=49:LOG00001_0050.CSV END
# n=50:LOG00001_0051.CSV END
# n=51:LOG00001_0052.CSV END
# n=52:LOG00001_0053.CSV END
# n=53:LOG00001_0054.CSV END
# n=54:LOG00001_0055.CSV END
# n=55:LOG00001_0056.CSV END
# n=56:LOG00001_0057.CSV END
# n=57:LOG00001_0058.CSV END
# n=58:LOG00001_0059.CSV END
# n=59:LOG00001_0060.CSV END
# n=60:LOG00001_0061.CSV END
# n=61:LOG00001_0062.CSV END
# n=62:LOG00001_0063.CSV END
# n=63:LOG00001_0064.CSV END
# n=64:LOG00001_0065.CSV END
# n=65:LOG00001_0066.CSV END
# n=66:LOG00001_0067.CSV END
# n=67:LOG00001_0068.CSV END
# n=68:LOG00001_0069.CSV END
# n=69:LOG00001_0070.CSV END
# n=70:LOG00001_0071.CSV END
# n=71:LOG00001_0072.CSV END
# n=72:LOG00001_0073.CSV END
# n=73:LOG00001_0074.CSV END
# n=74:LOG00001_0075.CSV END
# n=75:LOG00001_0076.CSV END
# n=76:LOG00001_0077.CSV END
# n=77:LOG00001_0078.CSV END
# n=78:LOG00001_0079.CSV END
# n=79:LOG00001_0080.CSV END
# n=80:LOG00001_0081.CSV END
# n=81:LOG00001_0082.CSV END
# n=82:LOG00001_0083.CSV END
# n=83:LOG00001_0084.CSV END
# n=84:LOG00001_0085.CSV END
# n=85:LOG00001_0086.CSV END
# n=86:LOG00001_0087.CSV END
# n=87:LOG00001_0088.CSV END
# n=88:LOG00001_0089.CSV END
# n=89:LOG00001_0090.CSV END
# n=90:LOG00001_0091.CSV END
# n=91:LOG00001_0092.CSV END
# n=92:LOG00001_0093.CSV END
# n=93:LOG00001_0094.CSV END
# n=94:LOG00001_0095.CSV END
# n=95:LOG00001_0096.CSV END
# n=96:LOG00001_0097.CSV END
# n=97:LOG00001_0098.CSV END
# n=98:LOG00001_0099.CSV END
# n=99:LOG00001_0100.CSV END
# n=100:LOG00001_0101.CSV END
# n=101:LOG00001_0102.CSV END
# n=102:LOG00001_0103.CSV END
# n=103:LOG00001_0104.CSV END
# n=104:LOG00001_0105.CSV END
# n=105:LOG00001_0106.CSV END
# n=106:LOG00001_0107.CSV END
# n=107:LOG00001_0108.CSV END
# n=108:LOG00001_0109.CSV END
# n=109:LOG00001_0110.CSV END
# n=110:LOG00001_0111.CSV END
# n=111:LOG00001_0112.CSV END
# n=112:LOG00001_0113.CSV END
# n=113:LOG00001_0114.CSV END
# n=114:LOG00001_0115.CSV END
# n=115:LOG00001_0116.CSV END
# n=116:LOG00001_0117.CSV END
# n=117:LOG00001_0118.CSV END
# n=118:LOG00001_0119.CSV END
# n=119:LOG00001_0120.CSV END
# n=120:LOG00001_0121.CSV END
# n=121:LOG00001_0122.CSV END
# n=122:LOG00001_0123.CSV END
# n=123:LOG00001_0124.CSV END
# n=124:LOG00001_0125.CSV END
# n=125:LOG00001_0126.CSV END
# n=126:LOG00001_0127.CSV END
# n=127:LOG00001_0128.CSV END
# n=128:LOG00001_0129.CSV END
# n=129:LOG00001_0130.CSV END
# n=130:LOG00001_0131.CSV END
# n=131:LOG00001_0132.CSV END
# n=132:LOG00001_0133.CSV END
# n=133:LOG00001_0134.CSV END
# n=134:LOG00001_0135.CSV END
# n=135:LOG00001_0136.CSV END
# n=136:LOG00001_0137.CSV END
# n=137:LOG00001_0138.CSV END
# n=138:LOG00001_0139.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=139:LOG00001_0140.CSV END
# n=140:LOG00001_0141.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=141:LOG00001_0142.CSV END
# n=142:LOG00001_0143.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=143:LOG00001_0144.CSV END
# n=144:LOG00001_0145.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=145:LOG00001_0146.CSV END
# n=146:LOG00001_0147.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=147:LOG00001_0148.CSV END
# n=148:LOG00001_0149.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=149:LOG00001_0150.CSV END
# n=150:LOG00001_0151.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=151:LOG00001_0152.CSV END
# n=152:LOG00001_0153.CSV END
# C:\Users\0296\AppData\Local\Temp\ipykernel_5084\3393724898.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _df[1] = (pd.to_datetime(_df[1])).dt.round("min")
# n=153:LOG00001_0154.CSV END
# n=154:LOG00001_0155.CSV END
# n=155:LOG00001_0156.CSV END
# n=156:LOG00001_0157.CSV END
# n=157:LOG00001_0158.CSV END
# n=158:LOG00001_0159.CSV END
# n=159:LOG00001_0160.CSV END
# n=160:LOG00001_0161.CSV END
# n=161:LOG00001_0162.CSV END
# n=162:LOG00001_0163.CSV END
# n=163:LOG00001_0164.CSV END
# n=164:LOG00001_0165.CSV END
# n=165:LOG00001_0166.CSV END
# n=166:LOG00001_0167.CSV END
# n=167:LOG00001_0168.CSV END
# n=168:LOG00001_0169.CSV END
# n=169:LOG00001_0170.CSV END
# n=170:LOG00001_0171.CSV END
# n=171:LOG00001_0172.CSV END
# n=172:LOG00001_0173.CSV END
# n=173:LOG00001_0174.CSV END
# n=174:LOG00001_0175.CSV END
# n=175:LOG00001_0176.CSV END
# n=176:LOG00001_0177.CSV END
# n=177:LOG00001_0178.CSV END
# n=178:LOG00001_0179.CSV END
# n=179:LOG00001_0180.CSV END
# n=180:LOG00001_0181.CSV END
# n=181:LOG00001_0182.CSV END
# n=182:LOG00001_0183.CSV END
# n=183:LOG00001_0184.CSV END
# n=184:LOG00001_0185.CSV END
# n=185:LOG00001_0186.CSV END
# n=186:LOG00001_0187.CSV END
# n=187:LOG00001_0188.CSV END
# n=188:LOG00001_0189.CSV END
# n=189:LOG00001_0190.CSV END
# n=190:LOG00001_0191.CSV END
# n=191:LOG00001_0192.CSV END
# n=192:LOG00001_0193.CSV END
# n=193:LOG00001_0194.CSV END
# n=194:LOG00001_0195.CSV END
# n=195:LOG00001_0196.CSV END
# n=196:LOG00001_0197.CSV END
# n=197:LOG00001_0198.CSV END
# n=198:LOG00001_0199.CSV END
# n=199:LOG00001_0200.CSV END
# n=200:LOG00001_0201.CSV END
# n=201:LOG00001_0202.CSV END
# n=202:LOG00001_0203.CSV END
# n=203:LOG00001_0204.CSV END
# n=204:LOG00001_0205.CSV END
# n=205:LOG00001_0206.CSV END
# n=206:LOG00001_0207.CSV END
# n=207:LOG00001_0208.CSV END
# n=208:LOG00001_0209.CSV END
# n=209:LOG00001_0210.CSV END
# n=210:LOG00001_0211.CSV END
# n=211:LOG00001_0212.CSV END
# n=212:LOG00001_0213.CSV END
# n=213:LOG00001_0214.CSV END
# n=214:LOG00001_0215.CSV END
# n=215:LOG00001_0216.CSV END
# n=216:LOG00001_0217.CSV END
# n=217:LOG00001_0218.CSV END
# n=218:LOG00001_0219.CSV END
# n=219:LOG00001_0220.CSV END
# n=220:LOG00001_0221.CSV END
# n=221:LOG00001_0222.CSV END
# n=222:LOG00001_0223.CSV END
# n=223:LOG00001_0224.CSV END
# n=224:LOG00001_0225.CSV END
# n=225:LOG00001_0226.CSV END
# n=226:LOG00001_0227.CSV END
# n=227:LOG00001_0228.CSV END
# n=228:LOG00001_0229.CSV END
# n=229:LOG00001_0230.CSV END
# n=230:LOG00001_0231.CSV END
# n=231:LOG00001_0232.CSV END
# n=232:LOG00001_0233.CSV END
# n=233:LOG00001_0234.CSV END
# n=234:LOG00001_0235.CSV END
# n=235:LOG00001_0236.CSV END
# n=236:LOG00001_0237.CSV END
# n=237:LOG00001_0238.CSV END
# n=238:LOG00001_0239.CSV END
# n=239:LOG00001_0240.CSV END
# n=240:LOG00001_0241.CSV END
# n=241:LOG00001_0242.CSV END
# n=242:LOG00001_0243.CSV END
# n=243:LOG00001_0244.CSV END
# n=244:LOG00001_0245.CSV END
# n=245:LOG00001_0246.CSV END
# n=246:LOG00001_0247.CSV END
# n=247:LOG00001_0248.CSV END
# n=248:LOG00001_0249.CSV END
# n=249:LOG00001_0250.CSV END
# n=250:LOG00001_0251.CSV END
# n=251:LOG00001_0252.CSV END
# n=252:LOG00001_0253.CSV END
# n=253:LOG00001_0254.CSV END
# n=254:LOG00001_0255.CSV END
# n=255:LOG00001_0256.CSV END
# n=256:LOG00001_0257.CSV END
# n=257:LOG00001_0258.CSV END
# n=258:LOG00001_0259.CSV END
# n=259:LOG00001_0260.CSV END
# n=260:LOG00001_0261.CSV END
# n=261:LOG00001_0262.CSV END
# n=262:LOG00001_0263.CSV END
# n=263:LOG00001_0264.CSV END
# n=264:LOG00001_0265.CSV END
# n=265:LOG00001_0266.CSV END
# n=266:LOG00001_0267.CSV END
# n=267:LOG00001_0268.CSV END
# n=268:LOG00001_0269.CSV END
# n=269:LOG00001_0270.CSV END
# n=270:LOG00001_0271.CSV END
# n=271:LOG00001_0272.CSV END
# n=272:LOG00001_0273.CSV END
# n=273:LOG00001_0274.CSV END
# n=274:LOG00001_0275.CSV END
# n=275:LOG00001_0276.CSV END
# n=276:LOG00001_0277.CSV END
# n=277:LOG00001_0278.CSV END
# n=278:LOG00001_0279.CSV END
# n=279:LOG00001_0280.CSV END
# n=280:LOG00001_0281.CSV END
# n=281:LOG00001_0282.CSV END
# n=282:LOG00001_0283.CSV END
# n=283:LOG00001_0284.CSV END
# n=284:LOG00001_0285.CSV END
# n=285:LOG00001_0286.CSV END
# n=286:LOG00001_0287.CSV END
# n=287:LOG00001_0288.CSV END
# n=288:LOG00001_0289.CSV END
# n=289:LOG00001_0290.CSV END
# n=290:LOG00001_0291.CSV END
# n=291:LOG00001_0292.CSV END
# n=292:LOG00001_0293.CSV END
# n=293:LOG00001_0294.CSV END
# n=294:LOG00001_0295.CSV END
# n=295:LOG00001_0296.CSV END
# n=296:LOG00001_0297.CSV END
# n=297:LOG00001_0298.CSV END
# n=298:LOG00001_0299.CSV END
# n=299:LOG00001_0300.CSV END
# n=300:LOG00001_0301.CSV END
# n=301:LOG00001_0302.CSV END
# n=302:LOG00001_0303.CSV END
# n=303:LOG00001_0304.CSV END
# n=304:LOG00001_0305.CSV END
# n=305:LOG00001_0306.CSV END
# n=306:LOG00001_0307.CSV END
# n=307:LOG00001_0308.CSV END
# n=308:LOG00001_0309.CSV END
# n=309:LOG00001_0310.CSV END
# n=310:LOG00001_0311.CSV END
# n=311:LOG00001_0312.CSV END
# n=312:LOG00001_0313.CSV END
# n=313:LOG00001_0314.CSV END
# n=314:LOG00001_0315.CSV END
# n=315:LOG00001_0316.CSV END
# n=316:LOG00001_0317.CSV END
# n=317:LOG00001_0318.CSV END
# n=318:LOG00001_0319.CSV END
# n=319:LOG00001_0320.CSV END
# n=320:LOG00001_0321.CSV END
# n=321:LOG00001_0322.CSV END
# n=322:LOG00001_0323.CSV END
# n=323:LOG00001_0324.CSV END
# n=324:LOG00001_0325.CSV END
# n=325:LOG00001_0326.CSV END
# n=326:LOG00001_0327.CSV END
# n=327:LOG00001_0328.CSV END
# n=328:LOG00001_0329.CSV END
# n=329:LOG00001_0330.CSV END
# n=330:LOG00001_0331.CSV END
# n=331:LOG00001_0332.CSV END
# n=332:LOG00001_0333.CSV END
# n=333:LOG00001_0334.CSV END
# n=334:LOG00001_0335.CSV END
# n=335:LOG00001_0336.CSV END
# n=336:LOG00001_0337.CSV END
# n=337:LOG00001_0338.CSV END
# n=338:LOG00001_0339.CSV END
# n=339:LOG00001_0340.CSV END
# n=340:LOG00001_0341.CSV END
# n=341:LOG00001_0342.CSV END
# n=342:LOG00001_0343.CSV END
# n=343:LOG00001_0344.CSV END
# n=344:LOG00001_0345.CSV END
# n=345:LOG00001_0346.CSV END
# n=346:LOG00001_0347.CSV END
# n=347:LOG00001_0348.CSV END
# n=348:LOG00001_0349.CSV END
# n=349:LOG00001_0350.CSV END
# n=350:LOG00001_0351.CSV END
# n=351:LOG00001_0352.CSV END
# n=352:LOG00001_0353.CSV END
# n=353:LOG00001_0354.CSV END
# n=354:LOG00001_0355.CSV END
# n=355:LOG00001_0356.CSV END
# n=356:LOG00001_0357.CSV END
# n=357:LOG00001_0358.CSV END
# n=358:LOG00001_0359.CSV END
# n=359:LOG00001_0360.CSV END
# n=360:LOG00001_0361.CSV END
# n=361:LOG00001_0362.CSV END
# n=362:LOG00001_0363.CSV END
# n=363:LOG00001_0364.CSV END
# n=364:LOG00001_0365.CSV END
# n=365:LOG00001_0366.CSV END
# n=366:LOG00001_0367.CSV END
# n=367:LOG00001_0368.CSV END
# n=368:LOG00001_0369.CSV END
# n=369:LOG00001_0370.CSV END
# n=370:LOG00001_0371.CSV END
# n=371:LOG00001_0372.CSV END
# n=372:LOG00001_0373.CSV END
# n=373:LOG00001_0374.CSV END
# n=374:LOG00001_0375.CSV END
# n=375:LOG00001_0376.CSV END
# n=376:LOG00001_0377.CSV END
# n=377:LOG00001_0378.CSV END
# n=378:LOG00001_0379.CSV END
# n=379:LOG00001_0380.CSV END
# n=380:LOG00001_0381.CSV END
# n=381:LOG00001_0382.CSV END
# n=382:LOG00001_0383.CSV END
# n=383:LOG00001_0384.CSV END
# n=384:LOG00001_0385.CSV END
# n=385:LOG00001_0386.CSV END
# n=386:LOG00001_0387.CSV END
# n=387:LOG00001_0388.CSV END
# n=388:LOG00001_0389.CSV END
# n=389:LOG00001_0390.CSV END
# n=390:LOG00001_0391.CSV END
# n=391:LOG00001_0392.CSV END
# n=392:LOG00001_0393.CSV END
# n=393:LOG00001_0394.CSV END
# n=394:LOG00001_0395.CSV END
# n=395:LOG00001_0396.CSV END
# n=396:LOG00001_0397.CSV END
# n=397:LOG00001_0398.CSV END
# n=398:LOG00001_0399.CSV END
# n=399:LOG00001_0400.CSV END
# n=400:LOG00001_0401.CSV END
# n=401:LOG00001_0402.CSV END
# n=402:LOG00001_0403.CSV END
# n=403:LOG00001_0404.CSV END
# n=404:LOG00001_0405.CSV END
# n=405:LOG00001_0406.CSV END
# n=406:LOG00001_0407.CSV END
# n=407:LOG00001_0408.CSV END
# n=408:LOG00001_0409.CSV END
# n=409:LOG00001_0410.CSV END
# n=410:LOG00001_0411.CSV END
# n=411:LOG00001_0412.CSV END
# n=412:LOG00001_0413.CSV END
# n=413:LOG00001_0414.CSV END
# n=414:LOG00001_0415.CSV END
# n=415:LOG00001_0416.CSV END
# n=416:LOG00001_0417.CSV END
# n=417:LOG00001_0418.CSV END
# n=418:LOG00001_0419.CSV END
# n=419:LOG00001_0420.CSV END
# n=420:LOG00001_0421.CSV END
# n=421:LOG00001_0422.CSV END
# n=422:LOG00001_0423.CSV END
# n=423:LOG00001_0424.CSV END
# n=424:LOG00001_0425.CSV END
# n=425:LOG00001_0426.CSV END
# n=426:LOG00001_0427.CSV END
# n=427:LOG00001_0428.CSV END
# n=428:LOG00001_0429.CSV END
# n=429:LOG00001_0430.CSV END
# n=430:LOG00001_0431.CSV END
# n=431:LOG00001_0432.CSV END
# n=432:LOG00001_0433.CSV END
# n=433:LOG00001_0434.CSV END
# n=434:LOG00001_0435.CSV END
# n=435:LOG00001_0436.CSV END
# n=436:LOG00001_0437.CSV END
# n=437:LOG00001_0438.CSV END
# n=438:LOG00001_0439.CSV END
# n=439:LOG00001_0440.CSV END
# n=440:LOG00001_0441.CSV END
# n=441:LOG00001_0442.CSV END
# n=442:LOG00001_0443.CSV END
# n=443:LOG00001_0444.CSV END
# n=444:LOG00001_0445.CSV END
# n=445:LOG00001_0446.CSV END
# n=446:LOG00001_0447.CSV END
# n=447:LOG00001_0448.CSV END
# n=448:LOG00001_0449.CSV END
# n=449:LOG00001_0450.CSV END
# n=450:LOG00001_0451.CSV END
# n=451:LOG00001_0452.CSV END
# n=452:LOG00001_0453.CSV END
# n=453:LOG00001_0454.CSV END
# n=454:LOG00001_0455.CSV END
# n=455:LOG00001_0456.CSV END
# n=456:LOG00001_0457.CSV END
# n=457:LOG00001_0458.CSV END
# n=458:LOG00001_0459.CSV END
# n=459:LOG00001_0460.CSV END
# n=460:LOG00001_0461.CSV END
# n=461:LOG00001_0462.CSV END
# n=462:LOG00001_0463.CSV END
# n=463:LOG00001_0464.CSV END
# n=464:LOG00001_0465.CSV END
# n=465:LOG00001_0466.CSV END
# n=466:LOG00001_0467.CSV END
# n=467:LOG00001_0468.CSV END
# n=468:LOG00001_0469.CSV END
# n=469:LOG00001_0470.CSV END
# n=470:LOG00001_0471.CSV END
# n=471:LOG00001_0472.CSV END
# n=472:LOG00001_0473.CSV END
# n=473:LOG00001_0474.CSV END
# n=474:LOG00001_0475.CSV END
# n=475:LOG00001_0476.CSV END
# n=476:LOG00001_0477.CSV END
# n=477:LOG00001_0478.CSV END
# n=478:LOG00001_0479.CSV END
# n=479:LOG00001_0480.CSV END
# n=480:LOG00001_0481.CSV END
# n=481:LOG00001_0482.CSV END
# n=482:LOG00001_0483.CSV END
# n=483:LOG00001_0484.CSV END
# n=484:LOG00001_0485.CSV END
# n=485:LOG00001_0486.CSV END
# n=486:LOG00001_0487.CSV END
# n=487:LOG00001_0488.CSV END
# n=488:LOG00001_0489.CSV END
# n=489:LOG00001_0490.CSV END
# n=490:LOG00001_0491.CSV END
# n=491:LOG00001_0492.CSV END
# n=492:LOG00001_0493.CSV END
# n=493:LOG00001_0494.CSV END
# n=494:LOG00001_0495.CSV END
# n=495:LOG00001_0496.CSV END
# n=496:LOG00001_0497.CSV END
# n=497:LOG00001_0498.CSV END
# n=498:LOG00001_0499.CSV END
# n=499:LOG00001_0500.CSV END
# n=500:LOG00001_0501.CSV END
# n=501:LOG00001_0502.CSV END
# n=502:LOG00001_0503.CSV END
# n=503:LOG00001_0504.CSV END
# n=504:LOG00001_0505.CSV END
# n=505:LOG00001_0506.CSV END
# n=506:LOG00001_0507.CSV END
# n=507:LOG00001_0508.CSV END
# n=508:LOG00001_0509.CSV END
# n=509:LOG00001_0510.CSV END
# n=510:LOG00001_0511.CSV END
# n=511:LOG00001_0512.CSV END
# n=512:LOG00001_0513.CSV END
# n=513:LOG00001_0514.CSV END
# n=514:LOG00001_0515.CSV END
# n=515:LOG00001_0516.CSV END
# n=516:LOG00001_0517.CSV END
# n=517:LOG00001_0518.CSV END
# n=518:LOG00001_0519.CSV END
# n=519:LOG00001_0520.CSV END
# n=520:LOG00001_0521.CSV END
# n=521:LOG00001_0522.CSV END
# n=522:LOG00001_0523.CSV END
# n=523:LOG00001_0524.CSV END
# n=524:LOG00001_0525.CSV END
# n=525:LOG00001_0526.CSV END
# n=526:LOG00001_0527.CSV END
# n=527:LOG00001_0528.CSV END
# n=528:LOG00001_0529.CSV END
# n=529:LOG00001_0530.CSV END
# n=530:LOG00001_0531.CSV END
# n=531:LOG00001_0532.CSV END
# n=532:LOG00001_0533.CSV END
# n=533:LOG00001_0534.CSV END
# n=534:LOG00001_0535.CSV END
# n=535:LOG00001_0536.CSV END
# n=536:LOG00001_0537.CSV END
# n=537:LOG00001_0538.CSV END
# n=538:LOG00001_0539.CSV END
# n=539:LOG00001_0540.CSV END
# n=540:LOG00001_0541.CSV END
# n=541:LOG00001_0542.CSV END
# n=542:LOG00001_0543.CSV END
# n=543:LOG00001_0544.CSV END
# n=544:LOG00001_0545.CSV END
# n=545:LOG00001_0546.CSV END
# n=546:LOG00001_0547.CSV END
# n=547:LOG00001_0548.CSV END
# n=548:LOG00001_0549.CSV END
# n=549:LOG00001_0550.CSV END
# n=550:LOG00001_0551.CSV END
# n=551:LOG00001_0552.CSV END
# n=552:LOG00001_0553.CSV END
# n=553:LOG00001_0554.CSV END
# n=554:LOG00001_0555.CSV END
# n=555:LOG00001_0556.CSV END
# n=556:LOG00001_0557.CSV END
# n=557:LOG00001_0558.CSV END
# n=558:LOG00001_0559.CSV END
# n=559:LOG00001_0560.CSV END
# n=560:LOG00001_0561.CSV END
# n=561:LOG00001_0562.CSV END
# n=562:LOG00001_0563.CSV END
# n=563:LOG00001_0564.CSV END
# n=564:LOG00001_0565.CSV END
# n=565:LOG00001_0566.CSV END
# n=566:LOG00001_0567.CSV END
# n=567:LOG00001_0568.CSV END
# n=568:LOG00001_0569.CSV END
# n=569:LOG00001_0570.CSV END
# n=570:LOG00001_0571.CSV END
# n=571:LOG00001_0572.CSV END
# n=572:LOG00001_0573.CSV END
# n=573:LOG00001_0574.CSV END
# n=574:LOG00001_0575.CSV END
# n=575:LOG00001_0576.CSV END
# n=576:LOG00001_0577.CSV END
# n=577:LOG00001_0578.CSV END
# n=578:LOG00001_0579.CSV END
# n=579:LOG00001_0580.CSV END
# n=580:LOG00001_0581.CSV END
# n=581:LOG00001_0582.CSV END
# n=582:LOG00001_0583.CSV END
# n=583:LOG00001_0584.CSV END
# n=584:LOG00001_0585.CSV END
# n=585:LOG00001_0586.CSV END
# n=586:LOG00001_0587.CSV END
# n=587:LOG00001_0588.CSV END
# n=588:LOG00001_0589.CSV END
# n=589:LOG00001_0590.CSV END
# n=590:LOG00001_0591.CSV END
# n=591:LOG00001_0592.CSV END
# n=592:LOG00001_0593.CSV END
# n=593:LOG00001_0594.CSV END
# n=594:LOG00001_0595.CSV END
# n=595:LOG00001_0596.CSV END
# n=596:LOG00001_0597.CSV END
# n=597:LOG00001_0598.CSV END
# n=598:LOG00001_0599.CSV END
# n=599:LOG00001_0600.CSV END
# n=600:LOG00001_0601.CSV END
# n=601:LOG00001_0602.CSV END
# n=602:LOG00001_0603.CSV END
# n=603:LOG00001_0604.CSV END
# n=604:LOG00001_0605.CSV END
# n=605:LOG00001_0606.CSV END
# n=606:LOG00001_0607.CSV END
# n=607:LOG00001_0608.CSV END
# n=608:LOG00001_0609.CSV END
# n=609:LOG00001_0610.CSV END
# n=610:LOG00001_0611.CSV END
# n=611:LOG00001_0612.CSV END
# n=612:LOG00001_0613.CSV END
# n=613:LOG00001_0614.CSV END
# n=614:LOG00001_0615.CSV END
# n=615:LOG00001_0616.CSV END
# n=616:LOG00001_0617.CSV END
# n=617:LOG00001_0618.CSV END
# n=618:LOG00001_0619.CSV END
# n=619:LOG00001_0620.CSV END
# n=620:LOG00001_0621.CSV END
# n=621:LOG00001_0622.CSV END
# n=622:LOG00001_0623.CSV END
# n=623:LOG00001_0624.CSV END
# n=624:LOG00001_0625.CSV END
# n=625:LOG00001_0626.CSV END
# n=626:LOG00001_0627.CSV END
# n=627:LOG00001_0628.CSV END
# n=628:LOG00001_0629.CSV END
# n=629:LOG00001_0630.CSV END
# n=630:LOG00001_0631.CSV END
# n=631:LOG00001_0632.CSV END
# n=632:LOG00001_0633.CSV END
# n=633:LOG00001_0634.CSV END
# n=634:LOG00001_0635.CSV END
# n=635:LOG00001_0636.CSV END
# n=636:LOG00001_0637.CSV END
# n=637:LOG00001_0638.CSV END
# n=638:LOG00001_0639.CSV END
# n=639:LOG00001_0640.CSV END
# n=640:LOG00001_0641.CSV END
# n=641:LOG00001_0642.CSV END
# n=642:LOG00001_0643.CSV END
# n=643:LOG00001_0644.CSV END
# n=644:LOG00001_0645.CSV END
# n=645:LOG00001_0646.CSV END
# n=646:LOG00001_0647.CSV END
# n=647:LOG00001_0648.CSV END
# n=648:LOG00001_0649.CSV END
# n=649:LOG00001_0650.CSV END
# n=650:LOG00001_0651.CSV END
# n=651:LOG00001_0652.CSV END
# n=652:LOG00001_0653.CSV END
# n=653:LOG00001_0654.CSV END
# n=654:LOG00001_0655.CSV END
# n=655:LOG00001_0656.CSV END

# %%
data = {1:[], 18:[], 19:[]}
df_out = pd.DataFrame(data)
df_out[1] = (pd.to_datetime(df_out[1])).dt.round("min")
n = 1
col_names = {1: 'Time',18: '冷却水送り温度',19: '排熱回収補給水温度'}

for log in log1_list:
    os.chdir(log1_dir)
    df = pd.read_csv(log, names = range(1,20,1), encoding="shift_jis", delimiter=",", dtype="object")
    _df = df[13:]
    _df = _df.drop(range(2,18,1), axis=1)
    _df[1] = (pd.to_datetime(_df[1])).dt.round("min")

    for i in range(0,len(df_import)):
        t_i = df_import.iloc[i,0]
        t_o = df_import.iloc[i,1]
        for j in range(0,len(_df)):
            t = _df.iloc[j,0]
            if t.month != n:
                os.chdir(output_dir)
                df_out = df_out.rename(columns=col_names)
                df_out.to_csv(out_dir+"log01_{:02}m.csv".format(n), encoding="shift_jis", index=False)
                print('log01_{:02}m.csv SAVED'.format(n))
                
                df_out = pd.DataFrame(data)
                df_out[1] = (pd.to_datetime(df_out[1])).dt.round("min")
                n = t.month
                os.chdir(log1_dir)
                
            if t.date() == t_i.date():
                t1 = int((t - t_i).seconds)
                t2 = int((t_o - t).seconds)
                t3 = int((t_o - t_i).seconds)
                if t1+t2==t3:
                    df_out = pd.concat([df_out,_df[j:j+1]], ignore_index=False)
                elif t1==t2+t3:
                    break
            elif (t - t_i).days > 0:
                break
    
    print('n={0}:{1} END'.format(n,log))
print('ALL END')
# Out:
# n=1:LOG00001_0001.CSV END
# n=1:LOG00001_0002.CSV END
# n=1:LOG00001_0003.CSV END
# n=1:LOG00001_0004.CSV END
# n=1:LOG00001_0005.CSV END
# n=1:LOG00001_0006.CSV END
# n=1:LOG00001_0007.CSV END
# n=1:LOG00001_0008.CSV END
# n=1:LOG00001_0009.CSV END
# n=1:LOG00001_0010.CSV END
# n=1:LOG00001_0011.CSV END
# n=1:LOG00001_0012.CSV END
# n=1:LOG00001_0013.CSV END
# n=1:LOG00001_0014.CSV END
# n=1:LOG00001_0015.CSV END
# n=1:LOG00001_0016.CSV END
# n=1:LOG00001_0017.CSV END
# n=1:LOG00001_0018.CSV END
# n=1:LOG00001_0019.CSV END
# n=1:LOG00001_0020.CSV END
# n=1:LOG00001_0021.CSV END
# n=1:LOG00001_0022.CSV END
# n=1:LOG00001_0023.CSV END
# n=1:LOG00001_0024.CSV END
# n=1:LOG00001_0025.CSV END
# n=1:LOG00001_0026.CSV END
# n=1:LOG00001_0027.CSV END
# n=1:LOG00001_0028.CSV END
# n=1:LOG00001_0029.CSV END
# n=1:LOG00001_0030.CSV END
# n=1:LOG00001_0031.CSV END
# n=1:LOG00001_0032.CSV END
# n=1:LOG00001_0033.CSV END
# n=1:LOG00001_0034.CSV END
# n=1:LOG00001_0035.CSV END
# n=1:LOG00001_0036.CSV END
# n=1:LOG00001_0037.CSV END
# n=1:LOG00001_0038.CSV END
# n=1:LOG00001_0039.CSV END
# n=1:LOG00001_0040.CSV END
# n=1:LOG00001_0041.CSV END
# n=1:LOG00001_0042.CSV END
# n=1:LOG00001_0043.CSV END
# n=1:LOG00001_0044.CSV END
# n=1:LOG00001_0045.CSV END
# n=1:LOG00001_0046.CSV END
# n=1:LOG00001_0047.CSV END
# n=1:LOG00001_0048.CSV END
# n=1:LOG00001_0049.CSV END
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# log01_01m.csv SAVED
# log01_02m.csv SAVED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#      18 t = _df.iloc[j,0]
#      19 if t.month != n:
# ---> 20     os.chdir(output_dir)
#      21     df_out = df_out.rename(columns=col_names)
#      22     df_out.to_csv(out_dir+"log01_{:02}m.csv".format(n), encoding="shift_jis", index=False)
#
# KeyboardInterrupt:

# %%
type(t.month)
# Out:
# int
